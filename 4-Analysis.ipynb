# %% [markdown]
# # Analysis

# %%
import pandas as pd

# %%
arima_predictions = pd.read_csv('data/arima_predictions', index_col='date')
arima_predictions.index = pd.to_datetime(arima_predictions.index)
arima_predictions
# Out:
#                     65807          65802          65804          65810  \
# date
# 2018-05-01  124546.038914   97684.464161  148184.832451  201396.968517
# 2018-06-01  125169.802562   98064.249991  149353.760900  202105.993874
# 2018-07-01  125760.381789   98360.364776  150456.588094  202585.449081
# 2018-08-01  126364.401331   98595.126886  151522.163437  202962.986466
# 2018-09-01  126997.888221   98788.004939  152567.198616  203300.201554
# 2018-10-01  127659.710730   98954.192982  153601.374266  203625.686574
# 2018-11-01  128341.930177   99104.630583  154630.298121  203951.827314
# 2018-12-01  129035.991324   99246.667011  155657.218590  204283.265627
# 2019-01-01  129735.463268   99384.911631  156684.017391  204621.108428
# 2019-02-01  130436.586027   99522.036744  157711.784553  204964.980095
# 2019-03-01  131137.754303   99659.435493  158741.151500  205313.992029
# 2019-04-01  131838.703734   99797.713530  159772.484000  205667.176404
# ...

# %%
prophet_predictions = pd.read_csv('data/prophet_predictions.csv', index_col='date')
prophet_predictions.index = pd.to_datetime(arima_predictions.index)
prophet_predictions
# Out:
#                     65807          65802          65804          65810  \
# date
# 2018-05-01  119418.769702   94384.058508  141373.742384  192674.418682
# 2018-06-01  119845.590691   94708.620711  141784.823179  193358.768033
# 2018-07-01  120259.053304   95008.056504  142120.825470  194120.748669
# 2018-08-01  120786.442542   95297.404547  142483.723870  194712.868091
# 2018-09-01  121248.642841   95558.999170  142857.746050  195206.261574
# 2018-10-01  121689.646257   95811.596339  143209.276756  195663.638491
# 2018-11-01  122081.086991   96054.583240  143576.683793  196182.205729
# 2018-12-01  122469.785702   96302.514425  143952.659296  196613.747829
# 2019-01-01  122863.317555   96610.398522  144370.783688  197055.539702
# 2019-02-01  123180.890391   96849.291269  144740.137020  197436.368424
# 2019-03-01  123730.804727   96833.119911  145142.913708  197346.328640
# 2019-04-01  124053.552023   97154.322961  145657.875960  198056.561423
# ...

# %% [markdown]
# todo:
# - for each zip code, decide which model to use: ARIMA or Prophet
#     - reference graphs in the visualizations folder, which include cross validation rmse values
#     - ARIMA models generally have the lower rmse's, but based on the charts may be overfitting, and have larger confidence interval ranges
#     - confidence interval is the shaded blue area around the prediction, and indicates an 80% certainty that the value will fall in that range
# - choose which zip code is best to invest in
#     - multiple ways to determine "best": highest average slope between points, greatest roi between endpoints, just pick one
#     - the answer might be the same between ARIMA and Prophet
# - caveats
#     - even our predicted/future data is already months old, so this isn't good data to make current investments from
#     - 2 years out may be too far for accurate predictions
# - future work
#     - more recent data
#     - determine good length to forecast over (we just chose 2 years arbitrarily)

# %% [markdown]
# ### test -Deric

# %%
from scipy import stats
import datetime as dt

arima_predictions['date_ordinal'] = arima_predictions.index.map(dt.datetime.toordinal)

for col in arima_predictions.columns[:-1]:
    slope = stats.linregress(arima_predictions['date_ordinal'], arima_predictions[col])[0]
    print(col, 'slope:', round(slope,2))
# Out:
# 65807 slope: 22.76
# 65802 slope: 4.99
# 65804 slope: 34.19
# 65810 slope: 11.8
# 65806 slope: 4.32
# 65809 slope: 69.41
